# %% [markdown]
# # CENG 111 Computer Programming -- Fall 2023 - 2024
# ## LAB 2 - Week 4

# %% [markdown]
# **Q1:** Write a Python program that prints the letter grade according to points that student have.
#
# If the score of the student is greater than or equal to 89, student should get “AA”, <br>
# If the score is greater than or equal to 79, student should get “BB”, <br>
# If the score is greater than or equal to 71, student should get “CC”, <br>
# If the score is greater than or equal to 61, student should get “DD”, <br>
# otherwise student will get “FF”.
#
# At the beginning of the Python program you must check whether the points is in a valid interval, which means points of a student should be greater than or equal to 0 and lower than 101.
#
# You must get students points (int) from the keyboard as an input.
#
# At the end print the result.

# %%
# Write your answer here.

# %% [markdown]
# **Q2:** Write a Python program that finds the greatest of three numbers. You must get three numbers (a, b, c) from the keyboard as an input. At the end print the result.

# %%
# Write your answer here.

# %% [markdown]
# **Q3:** Write the Python program that generates the shape shown in the image below.

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
# Write your answer here.

# %% [markdown]
# **Q4:** Write the Python program that finds the third smallest value in the list named "numbers". At the end print the result.

# %%
# Write your answer here.
